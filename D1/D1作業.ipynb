# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
w = 3
b = 0.5
x_lin = np.linspace(0, 100, 101)
y = (x_lin + np.random.randn(101) * 5) * w + b
plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
def mean_absolute_error(y, yp):
    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae
MAE = mean_absolute_error(y, y_hat)
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean absolute error is 11.005

# %%
def mean_squared_error(y,yp):
    mse=MSE= sum((y-yp)**2)
    return mse
MSE = mean_squared_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
# Out:
# The Mean squared error is 19546.196

# %% [markdown]
# HW2
# 1.我選擇的資料是Data Police shootings(Database of every fatal shooting in the United States by a police officer)，選擇這組資料的原因是，美國時常發生警察開搶導致傷亡的事件，而在這些受害人中又大部分是有色人種。藉由分析其槍殺的人種以及所在州可以警惕潛在受害者。
# 2.資寮來源於Andriy Samoshin，FBI and the Centers for Disease Control and Prevention。
# 3.資料型態為結構化資料
# 4.藉由數據分析可以評斷此員警是否對特定人種進行開槍的動作。達到預防及懲處的目的。

# %% [markdown]
# HW3
# 1.我認為核心問題是載客人數以及載客里程，自由載客車隊的業績體現於載客數以及其里程數(里程數越高價格越高)
# 2.資料由司機蒐集，可以依照地點區分，例如此地點載客人數多或是此地點旅客里程數交高等等。天氣或是節日可能會影響資料的準確度。
# 3.資料型態為結構化資料
# 4.依照地點區分派駐若干司機進行載客業務，撇除節日因素，針對各地點算出載客率(載客人數/小時)以及每人單價(價錢/載客人數)做區分，在載客率較高的地點派駐更多司機，在每人單價較高的地點派駐舒適大型車，我認為有效提升業績。
